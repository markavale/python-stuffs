# %%
from datasets import load_dataset

# %%
data_name = "Gustavosta/Stable-Diffusion-Prompts"
training_data = load_dataset(data_name, split="train")

# %%
list(map(lambda x: x, training_data))[:1]
# Out:
# [{'Prompt': 'realistic car 3 d render sci - fi car and sci - fi robotic factory structure in the coronation of napoleon painting and digital billboard with point cloud in the middle, unreal engine 5, keyshot, octane, artstation trending, ultra high detail, ultra realistic, cinematic, 8 k, 1 6 k, in style of zaha hadid, in style of nanospace michael menzelincev, in style of lee souder, in plastic, dark atmosphere, tilt shift, depth of field,'}]

# %%
import matplotlib.pyplot as plt
import pandas as pd
import nltk
from collections import Counter
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/dev/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text = " ".join([item['Prompt'] for item in training_data])

# %%
# Tokenization (splitting the text into words)
words = nltk.word_tokenize(text)

# Removing punctuation and making all the words lowercase
words = [word.lower() for word in words if word.isalpha()]

# Removing stopwords from all available languages
all_stopwords = set()
for lang in stopwords.fileids():
    all_stopwords.update(stopwords.words(lang))

words = [word for word in words if word not in all_stopwords]

# Counting word frequencies
word_counter = Counter(words)

# Most common words
common_words = word_counter.most_common(10)

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(*zip(*common_words))
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title('Top 10 Most Common Words')
plt.show()
